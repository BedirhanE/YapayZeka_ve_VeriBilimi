# %% [markdown]
# ÇAPRAZLAMALAR
#
# kırılımları göz önünde bulundurmak için kullanılır.

# %%
import seaborn as sns   
from pandas.api.types import CategoricalDtype
diamonda = sns.load_dataset('diamonds')
df= diamonda.copy()
cut_kategoriler = ["Fair","Good","Very Good","Premium","Ideal"]
df.cut = df.cut.astype(CategoricalDtype(categories = cut_kategoriler, ordered = True))
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.catplot(x = "cut", y = "price", hue = "color", kind = "point", data = df);# iki kategorik değişkenin ilişkisini göstermek için kullanılır.

# %%
sns.barplot(x = "cut", y = "price", hue = "color", data = df); # barplot ile kategorik değişkenlerin ortalamalarını görebiliriz.
#daha fazla açıklanabilirlik elde etmiş olduk bu yöntemelri kullanarak.

# %% [markdown]
# amaç büyük resme erişmek
# -veriyi görselleştirdikten sonra yeni boyutlar ekleyerek yeni bilgiler ortaya çıkarma işlemi yapıyoruz.

# %%
df.groupby(["cut","color"])["price"].mean()# gruplama işlemi yaparak daha fazla açıklanabilirlik elde etmiş olduk.
# Out:
# C:\Users\bedir\AppData\Local\Temp\ipykernel_17244\2134070832.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(["cut","color"])["price"].mean()# gruplama işlemi yaparak daha fazla açıklanabilirlik elde etmiş olduk.
# cut        color
# Fair       D        4291.061350
#            E        3682.312500
#            F        3827.003205
#            G        4239.254777
#            H        5135.683168
#            I        4685.445714
#            J        4975.655462
# Good       D        3405.382175
#            E        3423.644159
#            F        3495.750275
#            G        4123.482204
#            H        4276.254986
#            I        5078.532567
#            J        4574.172638
# Very Good  D        3470.467284
#            E        3214.652083
# ...

# %%
import seaborn as sns
diamonda = sns.load_dataset('diamonds')
df= diamonda.copy()
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.displot(df.price, kde = False); # histogram grafiği oluşturma işlemi yapar.
#elimizdeki sayısal değerleri belli aralıklara böler ve bu aralıkların frekanslarını gösterir.

# %%
sns.displot(df.price,bins=1000, kde = False); # bins parametresi ile aralıkların sayısını arttırabiliriz.

# %%
sns.distplot(df.price,hist=True);# distplot ile histogram grafiğinin üzerine yoğunluk grafiğini ekleyebiliriz.
# Out:
# C:\Users\bedir\AppData\Local\Temp\ipykernel_17244\12550116.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.price,hist=True);# distplot ile histogram grafiğinin üzerine yoğunluk grafiğini ekleyebiliriz.

# %%
sns.distplot(df.price,hist=False);#Sadece değerlerin yoğunluk grafiğini gösterir.
# Out:
# C:\Users\bedir\AppData\Local\Temp\ipykernel_17244\1340207404.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.price,hist=False);#Sadece değerlerin yoğunluk grafiğini gösterir.

# %%
sns.kdeplot(df.price,shade=True);# sadece yoğunluk grafiğini gösterir.grafiğin altını boyayarak gösterir.
# Out:
# C:\Users\bedir\AppData\Local\Temp\ipykernel_17244\545569072.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df.price,shade=True);# sadece yoğunluk grafiğini gösterir.grafiğin altını boyayarak gösterir.

# %% [markdown]
# ÇAPRAZLAMALAR
# histogram içinde belli başlı bazı çaprazlama işlemleri yapıcaz.

# %%
import seaborn as sns
diamonda = sns.load_dataset('diamonds')
df= diamonda.copy()
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.kdeplot(df.price,shade=True);#iki değişkenin yoğunluk grafiğini gösterir.
# Out:
# C:\Users\bedir\AppData\Local\Temp\ipykernel_17244\2782581553.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df.price,shade=True);#iki değişkenin yoğunluk grafiğini gösterir.

# %%
sns.FacetGrid(df, hue = "cut", height = 5).map(sns.kdeplot, "price",shade=True).add_legend();# FacetGrid ile iki değişkenin yoğunluk grafiğini gösterir.
# Out:
# c:\Users\bedir\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# c:\Users\bedir\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# c:\Users\bedir\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# ...

# %%
sns.catplot(x = "cut", y = "price", hue = "color",kind = "point", data = df);# catplot ile iki değişkenin ilişkisini gösterir.

# %%
import seaborn as sns
tips= sns.load_dataset('tips')  
df= tips.copy()
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.describe().T # veri setinin istatistiksel özetini gösterir.
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
df["sex"].value_counts() # kategorik değişkenin sınıflarının frekanslarını gösterir.
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
df["day"].value_counts() # kategorik değişkenin sınıflarının frekanslarını gösterir.
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
sns.boxenplot(x=df["total_bill"]);# boxenplot ile kutu grafiğinin içindeki kutuların sayısını arttırabiliriz.

# %%
df.describe().T # veri setinin istatistiksel özetini gösterir.
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %% [markdown]
# HANGİ GÜNLER DAHA FAZLA KAZANIYORUZ ?

# %%
sns.boxplot(x="day",y="total_bill",data=df);# boxplot ile kategorik değişkenin sınıflarının sayısal değişkenin dağılımını gösterir.

# %% [markdown]
# SABAH MI YOKSA AKŞAMMI DAHA ÇOK KAZANIYORUZ ?

# %%
sns.boxplot(x="time",y="total_bill",data=df);

# %%
#kişi sayısı ve kazanç oranı 
sns.boxplot(x="size",y="total_bill",data=df);

# %%
sns.boxplot(x="day",y="total_bill",hue="sex",data=df);

# %%
sns.catplot(y="total_bill",kind="violin",data=df);# catplot ile kategorik değişkenin sınıflarının sayısal değişkenin dağılımını gösterir.violin grafiği ile gösterir.

# %%
sns.catplot(x="day", y= "total_bill",kind="violin",data=df);# catplot ile kategorik değişkenin sınıflarının sayısal değişkenin dağılımını gösterir.violin grafiği ile gösterir.

# %% [markdown]
# Yoğunluk ve bok grafiğinin kesişimi ile bir grafik oluşturuyor.

# %%
sns.catplot(x="day",y="total_bill" , hue="sex",kind="violin",data=df);

# %%
sns.scatterplot(x="total_bill",y="tip",data=df);# scatterplot ile iki sayısal değişkenin ilişkisini gösterir.
#sayısal değerler arasındaki ilişkiyi gösterir.

# %% [markdown]
#               ÇAPRAZLAMALAR

# %%
sns.scatterplot(x="total_bill",y="tip",hue="time",data=df);

# %% [markdown]
# yukarıdaki grafikte ödenen hesap arttıkça ödenen bahşiş de arttığını çok rahat görebiliyoruz.

# %%
sns.scatterplot(x="total_bill",y="tip",hue="time",style="time",data=df);

# %%
sns.scatterplot(x="total_bill",y="tip",size="size",hue="size",data=df);
# size parametresi ile noktaların büyüklüğünü değiştirebiliriz.

# %% [markdown]
# Heatmap
# ısı haritası

# %%
import seaborn as sns
flights = sns.load_dataset('flights')
df= flights.copy()
df.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
df.shape
# Out:
# (144, 3)

# %%
df["passengers"].describe().T
# Out:
# count    144.000000
# mean     280.298611
# std      119.966317
# min      104.000000
# 25%      180.000000
# 50%      265.500000
# 75%      360.500000
# max      622.000000
# Name: passengers, dtype: float64

# %%
sns.heatmap(df);

# %%
sns.heatmap(df,annot=True,fmt="d",linewidths=.5);# annot parametresi ile sayısal değerleri gösterebiliriz.
